# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# Import our input dataset
diabetes_df = pd.read_csv('Resources/diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Remove diabetes outcome target from features data
y = diabetes_df.Outcome
X = diabetes_df.drop(columns="Outcome")

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)
# Out:
# 751    0
# 358    0
# 718    0
# 536    0
# 651    0
#       ..
# 676    1
# 113    0
# 556    0
# 152    1
# 107    0
# Name: Outcome, Length: 576, dtype: int64

# %%
# Preprocess numerical data for neural network
import numpy as np

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
# Out:
# array([[ 2.76992089, -0.5282092 ,  0.15146192, ..., -0.11007904,
#         -0.04565848,  0.37608507],
#        [ 0.05087717,  0.196342  ,  1.00782574, ...,  0.31007806,
#          0.35386232, -0.46648591],
#        [-0.55335477, -0.84323146,  0.36555287, ..., -0.0591509 ,
#          0.50706202, -0.8877714 ],
#        ...,
#        [-1.15758671, -0.46520475,  0.04441644, ...,  0.93394769,
#          0.37488973, -0.97202849],
#        [ 0.35299314,  0.10183532,  0.2585074 , ...,  0.24641789,
#         -0.78161784,  0.37608507],
#        [-0.2512388 ,  0.22784423,  0.15146192, ...,  0.04270536,
#          0.20667045, -0.55074301]])

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.729

# %%
# Define the basic neural network model
import numpy as np

nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, np.asarray(y_train), epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,np.asarray(y_test),verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Train on 576 samples
# Epoch 1/50
# 576/576 [==============================] - 0s 632us/sample - loss: 0.7051 - accuracy: 0.5851
# Epoch 2/50
# 576/576 [==============================] - 0s 33us/sample - loss: 0.6657 - accuracy: 0.6233
# Epoch 3/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.6326 - accuracy: 0.6684
# Epoch 4/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.6052 - accuracy: 0.7066
# Epoch 5/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.5826 - accuracy: 0.7049
# Epoch 6/50
# 576/576 [==============================] - 0s 29us/sample - loss: 0.5637 - accuracy: 0.7257
# Epoch 7/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.5478 - accuracy: 0.7292
# Epoch 8/50
# 576/576 [==============================] - 0s 29us/sample - loss: 0.5347 - accuracy: 0.7344
# Epoch 9/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.5227 - accuracy: 0.7413
# Epoch 10/50
# 576/576 [==============================] - 0s 29us/sample - loss: 0.5131 - accuracy: 0.7552
# Epoch 11/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.5042 - accuracy: 0.7691
# Epoch 12/50
# 576/576 [==============================] - 0s 29us/sample - loss: 0.4967 - accuracy: 0.7726
# Epoch 13/50
# 576/576 [==============================] - 0s 29us/sample - loss: 0.4905 - accuracy: 0.7795
# Epoch 14/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.4847 - accuracy: 0.7917
# Epoch 15/50
# 576/576 [==============================] - 0s 31us/sample - loss: 0.4797 - accuracy: 0.7917
# Epoch 16/50
# 576/576 [==============================] - 0s 32us/sample - loss: 0.4752 - accuracy: 0.7986
# Epoch 17/50
# 576/576 [==============================] - 0s 29us/sample - loss: 0.4714 - accuracy: 0.8073
# Epoch 18/50
# 576/576 [==============================] - 0s 29us/sample - loss: 0.4681 - accuracy: 0.8056
# Epoch 19/50
# 576/576 [==============================] - 0s 29us/sample - loss: 0.4650 - accuracy: 0.8056
# Epoch 20/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.4624 - accuracy: 0.8038
# Epoch 21/50
# 576/576 [==============================] - 0s 29us/sample - loss: 0.4603 - accuracy: 0.8038
# Epoch 22/50
# 576/576 [==============================] - 0s 29us/sample - loss: 0.4578 - accuracy: 0.8003
# Epoch 23/50
# 576/576 [==============================] - 0s 29us/sample - loss: 0.4560 - accuracy: 0.7986
# Epoch 24/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.4543 - accuracy: 0.7969
# Epoch 25/50
# 576/576 [==============================] - 0s 28us/sample - loss: 0.4529 - accuracy: 0.8003
# Epoch 26/50
# 576/576 [==============================] - 0s 29us/sample - loss: 0.4514 - accuracy: 0.7986
# Epoch 27/50
# 576/576 [==============================] - 0s 31us/sample - loss: 0.4503 - accuracy: 0.8003
# Epoch 28/50
# 576/576 [==============================] - 0s 29us/sample - loss: 0.4490 - accuracy: 0.7986
# Epoch 29/50
# 576/576 [==============================] - 0s 28us/sample - loss: 0.4482 - accuracy: 0.7986
# Epoch 30/50
# 576/576 [==============================] - 0s 29us/sample - loss: 0.4470 - accuracy: 0.8021
# Epoch 31/50
# 576/576 [==============================] - 0s 31us/sample - loss: 0.4462 - accuracy: 0.8003
# Epoch 32/50
# 576/576 [==============================] - 0s 28us/sample - loss: 0.4458 - accuracy: 0.8003
# Epoch 33/50
# 576/576 [==============================] - 0s 29us/sample - loss: 0.4447 - accuracy: 0.8003
# Epoch 34/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.4438 - accuracy: 0.8003
# Epoch 35/50
# 576/576 [==============================] - 0s 31us/sample - loss: 0.4429 - accuracy: 0.8021
# Epoch 36/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.4424 - accuracy: 0.8003
# Epoch 37/50
# 576/576 [==============================] - 0s 31us/sample - loss: 0.4416 - accuracy: 0.8003
# Epoch 38/50
# 576/576 [==============================] - 0s 31us/sample - loss: 0.4413 - accuracy: 0.8021
# Epoch 39/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.4405 - accuracy: 0.8021
# Epoch 40/50
# 576/576 [==============================] - 0s 28us/sample - loss: 0.4396 - accuracy: 0.8003
# Epoch 41/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.4396 - accuracy: 0.8003
# Epoch 42/50
# 576/576 [==============================] - 0s 32us/sample - loss: 0.4385 - accuracy: 0.8021
# Epoch 43/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.4381 - accuracy: 0.8021
# Epoch 44/50
# 576/576 [==============================] - 0s 29us/sample - loss: 0.4376 - accuracy: 0.8021
# Epoch 45/50
# 576/576 [==============================] - 0s 33us/sample - loss: 0.4371 - accuracy: 0.8021
# Epoch 46/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.4368 - accuracy: 0.8021
# Epoch 47/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.4359 - accuracy: 0.8021
# Epoch 48/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.4358 - accuracy: 0.8021
# Epoch 49/50
# 576/576 [==============================] - 0s 33us/sample - loss: 0.4353 - accuracy: 0.8021
# Epoch 50/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.4349 - accuracy: 0.8003
# 192/1 - 0s - loss: 0.4808 - accuracy: 0.7344
# Loss: 0.4791838675737381, Accuracy: 0.734375
